# %% [markdown]
# <a href="https://colab.research.google.com/github/myfirstgithub0512/Shruti_INFO5731_Spring2020/blob/master/Copy_of_In_class_exercise_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fourth in-class-exercise**

# %% [markdown]
# # 1. Text Data Preprocessing
#
# Here is a [legal case](https://github.com/unt-iialab/INFO5731_Spring2020/blob/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# ## 1.1 Basic feature extraction using text data
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# ## 1.2 Basic Text Pre-processing of text data
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# ## 1.3 Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above.
#
#
# ## 1.4 Advance Text Processing
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 2-grams terms as features.

# %%
# 1.1
# !pip install unidecode
# !pip instal counter
import urllib.request
import string
from unidecode import unidecode
import re
import nltk
import csv
import pandas as pd
import nltk.util
from collections import Counter
from textblob import TextBlob
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

ps = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()
stop =stopwords.words('english')

## Opening given legal file to read ##
filenamedata ="/content/Adams v Tanner.txt"
with open(filenamedata) as file_object:
   contents =file_object.read()
   #print(contents)
   words= contents.split()

################# Count number of sentences in the given file ##############
count =0
with open(filenamedata) as file_object:
    for line_read in file_object:
        count += 1
print("There are {0} sentences in the file".format(count))

################# Count number of words in the given file ##############

number_words=len(words)
print("Total words of" + filenamedata ,"is" , str(number_words))

################# average number of words in the given file ##############

words=0
wordslist=contents.split()
words=len(wordslist)
average= sum(len(word) for word in wordslist)/words    
print("Average=",average)

################# Count number of characters in the given file ##############

number_of_characters = len(contents)
print('Number of characters in text file :', number_of_characters)

################# Count number of special characters in the given file ##############


filename="/content/Adams v Tanner.txt"
words=contents.split()
number_words=len(words)
special_chars = "!#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
new=sum(v for k, v in Counter(words).items() if k in special_chars)
print("Total Special Characters", new)

################# Count number of numerics in the given file ##############

words=sum(map(str.isdigit, contents) )
print("Total Numeric in a text file =",words)

################# Count number of uppercase words in the given file ##############

words=sum(map(str.isupper, contents))
print("total uppercase words in a textfile =",words)

########### To count number of stop words in the given file ################
stop_words_count=0
stop =stopwords.words('english')
with open(filenamedata) as file_object:
    content =file_object.read()
    words =content.split()
    for word_read in words:
        if word_read in stop:
           stop_words_count += 1
print("There are {0} stop words in legal case file".format(stop_words_count))

#### 1.2 #####
##################################################################################################################################
#######################################################################################
with open(filenamedata) as file_object:
    content =file_object.read().lower()    ## Converting to lower case
    content =unidecode(content).replace('"', '').replace("'", '')
    translator = str.maketrans('','',string.punctuation)
    content =(unidecode(content).translate(translator)) ## Getting text without punctuation marks
    print("without_punctuation_list",content)

## Below is getting text without stop words
content = [word for word in content.split() if word not in stop]
print(("List without stop words",content)) ## List type

## List of 10 most common words
most_common_words= [word for word, word_count in Counter(content).most_common(10)]
print("Most Common Words", most_common_words)

## List of 10 most rare words
rare_words= [word for word, word_count in Counter(content).most_common()[:-10-1:-1]]
print("Most rare words", rare_words)

## print list without most frequest words
content = [word for word in content if word not in most_common_words]
print("List without most frequent words", content)
print(len(content)) ## 1586

## print list without most rare words
content = [word for word in content if word not in rare_words]
print("List without most rare words", content)
print(len(content)) ## 1576

content =' '.join(content) ## Converting List to String

## Check for spelling in given text
content=TextBlob(content).correct()

## Word Tokenizing text
content =word_tokenize(str(content))

## Stemming text
for w in content: 
    print(w, " : ", ps.stem(w)) 

## Lemmatization of text
for word in content:
    print(word,wordnet_lemmatizer.lemmatize(word))

df = pd.DataFrame(content)
df
export_csv = df.to_csv (r'C:\Users\mathu\OneDrive.csv', index = None, header=True) 
print (df)

## Calculate frequency of words in list
idx = pd.Index(content, name='Legal') ## Creating the index
print(idx.value_counts())

content=word_tokenize(str(content))
bigrams= ngrams(content,2)
print(bigrams)
##################################################################################################################################
#######################################################################################
# Out:
# ...
# ERROR: unknown command "instal" - maybe you meant "install"
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# There are 159 sentences in the file
# Total words of/content/Adams v Tanner.txt is 3707
# Average= 4.510385756676558
# Number of characters in text file : 20454
# Total Special Characters 13
# Total Numeric in a text file = 356
# total uppercase words in a textfile = 695
# There are 1679 stop words in legal case file
# without_punctuation_list
# 5 ala 740
# supreme court of alabama
# adams
# v
# tanner and horton
# june term 1843
# synopsis
# writ of error to the circuit court of sumter
#
#
#
# west headnotes 2
#
#
# 1
# chattel mortgages
# crops
# ...

# %% [markdown]
# # 2. Python Regular Expression

# %% [markdown]
# ## 2.1 Write a Python program to remove leading zeros from an IP address.
#
# ip = "260.08.094.109"

# %%
import re
ip_address = "260.08.094.109"
number = re.sub('\.[0]*','.',ip_address)
print(number)
# Out:
# 260.8.94.109

# %% [markdown]
# ## 2.2 Write a Python Program to extract all the years from the following sentence.
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
import re
sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."
e = re.findall(r'[2]\d{3}',sentence)
print(e)
# Out:
# ['2010', '2010', '2019']
